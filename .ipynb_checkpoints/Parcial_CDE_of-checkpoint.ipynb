# %%
# Examen parcial de CDE
import pandas as pd

linkco2= "https://github.com/NicoTCV/Parcial_CDE/raw/main/export_CO2.csv"
linkscore="https://github.com/NicoTCV/Parcial_CDE/raw/main/rise-2016-database-for-download.xlsx" # score por tipo de energía
linkwp="https://github.com/NicoTCV/Parcial_CDE/raw/main/6.1.%20Total_World_Production.xlsx" # producción minera

dataco2=pd.read_csv(linkco2,sep=';')
datascore=pd.read_excel(linkscore)
datawp=pd.read_excel(linkwp)

# %%
dataco2
# Out:
#                                               name  \
# 0                                            China
# 1                                    United States
# 2                                            India
# 3                                           Russia
# 4                                            Japan
# ..                                             ...
# 213                                     Antarctica
# 214  Saint Helena, Ascension, and Tristan da Cunha
# 215                                           Niue
# 216                       Northern Mariana Islands
# 217                                         Tuvalu
#
#                                             slug           value  \
# 0                                          china  10,773,248,000
# 1                                  united-states   5,144,361,000
# 2                                          india   2,314,738,000
# 3                                         russia   1,848,070,000
# 4                                          japan   1,103,234,000
# ..                                           ...             ...
# 213                                   antarctica          28,000
# 214  saint-helena-ascension-and-tristan-da-cunha          13,000
# 215                                         niue           8,000
# 216                     northern-mariana-islands               0
# 217                                       tuvalu               0
#
#      date_of_information  ranking                   region
# 0                   2019        1  East and Southeast Asia
# 1                   2019        2            North America
# 2                   2019        3               South Asia
# 3                   2019        4             Central Asia
# 4                   2019        5  East and Southeast Asia
# ..                   ...      ...                      ...
# 213                 2019      214               Antarctica
# 214                 2019      215                   Africa
# 215                 2019      216    Australia and Oceania
# 216                 2019      217    Australia and Oceania
# 217                 2019      218    Australia and Oceania
#
# [218 rows x 6 columns]

# %%
datascore
# Out:
#     Country Categories                  Unnamed: 1           Unnamed: 2  \
# 0              Country                      Region         Income group
# 1          Afghanistan                  South Asia           Low income
# 2              Algeria  Middle East & North Africa  Upper middle income
# 3               Angola          Sub-Saharan Africa  Upper middle income
# 4            Argentina   Latin America & Caribbean          High income
# ..                 ...                         ...                  ...
# 107      Venezuela, RB   Latin America & Caribbean          High income
# 108            Vietnam         East Asia & Pacific  Lower middle income
# 109        Yemen, Rep.  Middle East & North Africa  Lower middle income
# 110             Zambia          Sub-Saharan Africa  Lower middle income
# 111           Zimbabwe          Sub-Saharan Africa           Low income
#
#      Unnamed: 3        Pillar Scores              Unnamed: 5  \
# 0           NaN  Energy Access score  Renewable Energy score
# 1           NaN            23.992691               26.934385
# 2           NaN                  100               51.101032
# 3           NaN            48.298507               17.361071
# 4           NaN                  100               52.781026
# ..          ...                  ...                     ...
# 107         NaN                  100               24.704107
# 108         NaN                  100                64.09256
# 109         NaN            19.235747               24.404623
# 110         NaN            61.446662               46.655607
# 111         NaN            42.342222               18.008677
#
#                   Unnamed: 6     Unnamed: 7  Unnamed: 8  \
# 0    Energy Efficiency score  Overall score         NaN
# 1                  17.898479      22.941852         NaN
# 2                  55.987654      69.029562         NaN
# 3                  17.749669      27.803083         NaN
# 4                  43.946208      65.575745         NaN
# ..                       ...            ...         ...
# 107                42.082782       55.59563         NaN
# 108                70.578704      78.223754         NaN
# 109                12.114198      18.584856         NaN
# 110                20.631614      42.911294         NaN
# 111                14.313272      24.888057         NaN
#
#                                  Pillar: Energy Access  ...  \
# 0    Indicator 1:  Existence and monitoring of offi...  ...
# 1                                                    0  ...
# 2                                                  100  ...
# 3                                                   80  ...
# 4                                                  100  ...
# ..                                                 ...  ...
# 107                                                100  ...
# 108                                                100  ...
# 109                                                  0  ...
# 110                                                 80  ...
# 111                                                 40  ...
#
#                                            Unnamed: 28  \
# 0    Indicator 11: Types of electricity rate struct...
# 1                                            33.333333
# 2                                            68.518519
# 3                                                   50
# 4                                            53.703704
# ..                                                 ...
# 107                                          81.481481
# 108                                          77.777778
# 109                                                 37
# 110                                          72.222222
# 111                                          81.481481
#
#                                            Unnamed: 29 Unnamed: 30  \
# 0    indicator 12: Carbon Pricing and Monitoring Me...         NaN
# 1                                                    0         NaN
# 2                                                    0         NaN
# 3                                                    0         NaN
# 4                                                    0         NaN
# ..                                                 ...         ...
# 107                                                  0         NaN
# 108                                                  0         NaN
# 109                                                  0         NaN
# 110                                                  0         NaN
# 111                                                  0         NaN
#
#                               Pillar: Renewable Energy  \
# 0    Indicator 1: Legal framework for renewable energy
# 1                                                   50
# 2                                                  100
# 3                                                    0
# 4                                                  100
# ..                                                 ...
# 107                                                100
# 108                                                100
# 109                                                 50
# 110                                                100
# 111                                                 50
#
#                                            Unnamed: 32  \
# 0    Indicator 2: Planning for renewable energy exp...
# 1                                            67.708333
# 2                                               86.875
# 3                                                31.25
# 4                                              36.9375
# ..                                                 ...
# 107                                             42.375
# 108                                           60.15625
# 109                                               62.5
# 110                                              18.75
# 111                                                  0
#
#                                            Unnamed: 33  \
# 0    Indicator 3: Incentives and regulatory support...
# 1                                                    0
# 2                                                 87.5
# 3                                                 37.5
# 4                                                   75
# ..                                                 ...
# 107                                               12.5
# 108                                                 75
# 109                                               37.5
# 110                                                 75
# 111                                               12.5
#
#                                            Unnamed: 34  \
# 0    Indicator 4: Attributes of financial and regul...
# 1                                                    0
# 2                                            55.555556
# 3                                                    0
# 4                                            55.555556
# ..                                                 ...
# 107                                                  0
# 108                                                100
# 109                                          11.111111
# 110                                          66.666667
# 111                                          33.333333
#
#                                      Unnamed: 35  \
# 0    Indicator 5: Network connection and pricing
# 1                                      61.111111
# 2                                      16.666667
# 3                                      16.666667
# 4                                      33.333333
# ..                                           ...
# 107                                            0
# 108                                    66.666667
# 109                                            0
# 110                                    16.666667
# 111                                            0
#
#                         Unnamed: 36  \
# 0    Indicator 6: Counterparty risk
# 1                           9.72125
# 2                             11.11
# 3                         36.110833
# 4                          68.64079
# ..                              ...
# 107                        18.05375
# 108                          46.825
# 109                         9.72125
# 110                       49.505914
# 111                       30.227407
#
#                                            Unnamed: 37
# 0    indicator 7: Carbon Pricing and Monitoring Mec...
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 107                                                  0
# 108                                                  0
# 109                                                  0
# 110                                                  0
# 111                                                  0
#
# [112 rows x 38 columns]

# %%
datawp
# Out:
#     6.1.8.1. Total Minerals Production 2021 by Country in metr. t; column A Countries, column B Total Production inclusive Bauxite, column C Total Production of Iron and Ferro-Alloy Metals, column D Total Production of Non-Ferrous Metals, column E Total Production of Precious Metals (tons), column F Total Production of Industrial Minerals inclusive Diamond, column G Total Production of Mineral Fuels.  \
# 0                                              Country
# 1                                                China
# 2                                        United States
# 3                                               Russia
# 4                                            Australia
# ..                                                 ...
# 162                                            Burundi
# 163                                               Mali
# 164                           Central African Republic
# 165                                      French Guiana
# 166                                              Total
#
#                 Unnamed: 1                   Unnamed: 2          Unnamed: 3  \
# 0    Total (incl. Bauxite)  Iron and Ferro-Alloy Metals  Non-Ferrous Metals
# 1               4639063663                    259466140            46919355
# 2               2216667393                     30260150             3177483
# 3               1676162754                     59782705             5388230
# 4               1309620617                    575173171             4302853
# ..                     ...                          ...                 ...
# 162                    375                          145                 229
# 163                     72                            0                   0
# 164                      1                            0                   0
# 165                      1                            0                   0
# 166            18276750490                   1682971493           107665438
#
#               Unnamed: 4                         Unnamed: 5     Unnamed: 6
# 0    Precious Metals (t)  Industrial Minerals (incl. Diam.)  Mineral Fuels
# 1                   3845                          174314400     4089959923
# 2                   1225                           91339426     2091889109
# 3                   1700                           37565412     1566859707
# 4                   1637                           19445978      607430574
# ..                   ...                                ...            ...
# 162                    1                                  0              0
# 163                   72                                  0              0
# 164                    1                                  0              0
# 165                    1                                  0              0
# 166                29604                          809971979    15296261104
#
# [167 rows x 7 columns]

# %%
dataco2.shape,datascore.shape, datawp.shape  # no tiene el mismo # de filas
# Out:
# ((218, 6), (112, 38), (167, 7))

# %%
#                     Trabajaré con dataco2
# solo quiero las columnas name, value y date_of_information

# %%
# borro las columnas que no deseo, y guardo cambios
dataco2.drop(columns=['slug','ranking','region','date_of_information'],inplace=True)

# %%
# cambio el nombre a las columnas
dataco2.rename(columns={'name':'Country','value':'CO2_en_2019'},inplace=True)
dataco2
# Out:
#                                            Country     CO2_en_2019
# 0                                            China  10,773,248,000
# 1                                    United States   5,144,361,000
# 2                                            India   2,314,738,000
# 3                                           Russia   1,848,070,000
# 4                                            Japan   1,103,234,000
# ..                                             ...             ...
# 213                                     Antarctica          28,000
# 214  Saint Helena, Ascension, and Tristan da Cunha          13,000
# 215                                           Niue           8,000
# 216                       Northern Mariana Islands               0
# 217                                         Tuvalu               0
#
# [218 rows x 2 columns]

# %%
#                  Trabajaré con datascore
# solo quiero las columnas Country, Renovable Energy score
# y el indicador 7: Carbon Pricing and Monitoring Mechanism

# %%
# como lo que borraré es mucho... eligiré el método loc

# %%
datascore=datascore.loc[:,['Country Categories','Unnamed: 5','Unnamed: 6']]
datascore
# Out:
#     Country Categories              Unnamed: 5               Unnamed: 6
# 0              Country  Renewable Energy score  Energy Efficiency score
# 1          Afghanistan               26.934385                17.898479
# 2              Algeria               51.101032                55.987654
# 3               Angola               17.361071                17.749669
# 4            Argentina               52.781026                43.946208
# ..                 ...                     ...                      ...
# 107      Venezuela, RB               24.704107                42.082782
# 108            Vietnam                64.09256                70.578704
# 109        Yemen, Rep.               24.404623                12.114198
# 110             Zambia               46.655607                20.631614
# 111           Zimbabwe               18.008677                14.313272
#
# [112 rows x 3 columns]

# %%
# cambio el nombre a las columnas
datascore.rename(columns={'Country Categories':'Country','Unnamed: 5':'Renewable Energy score','Unnamed: 6':'Energy_Efficiency_score'},inplace=True)
# elimino la primera fila a NaN
import numpy as np
datascore.loc[0]=np.nan
datascore
# Out:
#            Country Renewable Energy score Energy_Efficiency_score
# 0              NaN                    NaN                     NaN
# 1      Afghanistan              26.934385               17.898479
# 2          Algeria              51.101032               55.987654
# 3           Angola              17.361071               17.749669
# 4        Argentina              52.781026               43.946208
# ..             ...                    ...                     ...
# 107  Venezuela, RB              24.704107               42.082782
# 108        Vietnam               64.09256               70.578704
# 109    Yemen, Rep.              24.404623               12.114198
# 110         Zambia              46.655607               20.631614
# 111       Zimbabwe              18.008677               14.313272
#
# [112 rows x 3 columns]

# %%
#          Trabajaré con datapm (producción minera)

# %%
# primero cambiaré el nombre de las columnas
datawp.rename(columns={'6.1.8.1. Total Minerals Production 2021 by Country in metr. t; column A Countries, column B Total Production inclusive Bauxite, column C Total Production of Iron and Ferro-Alloy Metals, column D Total Production of Non-Ferrous Metals, column E Total Production of Precious Metals (tons), column F Total Production of Industrial Minerals inclusive Diamond, column G Total Production of Mineral Fuels.':'Country','Unnamed: 6':'Mineral Fuels'},inplace=True)
datawp
# Out:
#                       Country             Unnamed: 1  \
# 0                     Country  Total (incl. Bauxite)
# 1                       China             4639063663
# 2               United States             2216667393
# 3                      Russia             1676162754
# 4                   Australia             1309620617
# ..                        ...                    ...
# 162                   Burundi                    375
# 163                      Mali                     72
# 164  Central African Republic                      1
# 165             French Guiana                      1
# 166                     Total            18276750490
#
#                       Unnamed: 2          Unnamed: 3           Unnamed: 4  \
# 0    Iron and Ferro-Alloy Metals  Non-Ferrous Metals  Precious Metals (t)
# 1                      259466140            46919355                 3845
# 2                       30260150             3177483                 1225
# 3                       59782705             5388230                 1700
# 4                      575173171             4302853                 1637
# ..                           ...                 ...                  ...
# 162                          145                 229                    1
# 163                            0                   0                   72
# 164                            0                   0                    1
# 165                            0                   0                    1
# 166                   1682971493           107665438                29604
#
#                             Unnamed: 5  Mineral Fuels
# 0    Industrial Minerals (incl. Diam.)  Mineral Fuels
# 1                            174314400     4089959923
# 2                             91339426     2091889109
# 3                             37565412     1566859707
# 4                             19445978      607430574
# ..                                 ...            ...
# 162                                  0              0
# 163                                  0              0
# 164                                  0              0
# 165                                  0              0
# 166                          809971979    15296261104
#
# [167 rows x 7 columns]

# %%
# Df con nuevo contenido
datawp=datawp.loc[:,['Country','Mineral Fuels']]
# cambio nombre de columnas
datawp
# Out:
#                       Country  Mineral Fuels
# 0                     Country  Mineral Fuels
# 1                       China     4089959923
# 2               United States     2091889109
# 3                      Russia     1566859707
# 4                   Australia      607430574
# ..                        ...            ...
# 162                   Burundi              0
# 163                      Mali              0
# 164  Central African Republic              0
# 165             French Guiana              0
# 166                     Total    15296261104
#
# [167 rows x 2 columns]

# %%
#  Ahora uniré las 3 tablas con merge

# %%
dataco2.shape,datascore.shape,datawp.shape
# Out:
# ((218, 2), (112, 3), (167, 2))

# %%
# usaré el método de fusión estándar

# %%
merge1=dataco2.merge(datascore,how='inner',left_on='Country',right_on='Country')
merge1
# Out:
#                      Country     CO2_en_2019 Renewable Energy score  \
# 0                      China  10,773,248,000              74.113095
# 1              United States   5,144,361,000              84.615079
# 2                      India   2,314,738,000              66.711397
# 3                      Japan   1,103,234,000              77.894841
# 4                    Germany     726,881,000               90.46627
# ..                       ...             ...                    ...
# 92                   Eritrea         798,000                 9.0525
# 93                   Burundi         715,000              53.568532
# 94           Solomon Islands         333,000              46.428155
# 95  Central African Republic         285,000              36.879881
# 96                   Vanuatu         225,000              16.889762
#
#    Energy_Efficiency_score
# 0                68.462978
# 1                 88.12037
# 2                60.267857
# 3                67.583841
# 4                77.091049
# ..                     ...
# 92               21.180556
# 93               12.436618
# 94                11.87996
# 95                10.99537
# 96                11.42802
#
# [97 rows x 4 columns]

# %%
merge2=merge1.merge(datawp,how='inner',left_on='Country',right_on='Country')
# cambiaré a mayúsculas la data merge2
merge2['Country']=merge2['Country'].str.upper()
merge2
# merge 2 es la unión de mis 3 datas
# Out:
#                      Country     CO2_en_2019 Renewable Energy score  \
# 0                      CHINA  10,773,248,000              74.113095
# 1              UNITED STATES   5,144,361,000              84.615079
# 2                      INDIA   2,314,738,000              66.711397
# 3                      JAPAN   1,103,234,000              77.894841
# 4                    GERMANY     726,881,000               90.46627
# ..                       ...             ...                    ...
# 87                    RWANDA       1,189,000              58.991964
# 88              SIERRA LEONE         899,000               7.539643
# 89                   ERITREA         798,000                 9.0525
# 90                   BURUNDI         715,000              53.568532
# 91  CENTRAL AFRICAN REPUBLIC         285,000              36.879881
#
#    Energy_Efficiency_score Mineral Fuels
# 0                68.462978    4089959923
# 1                 88.12037    2091889109
# 2                60.267857     881874005
# 3                67.583841       2285200
# 4                77.091049     133090212
# ..                     ...           ...
# 87               21.455026             0
# 88               18.270503             0
# 89               21.180556             0
# 90               12.436618             0
# 91                10.99537             0
#
# [92 rows x 5 columns]

# %%
# agrego data que mandó el profesor

# %%
linkteach='https://github.com/NicoTCV/Parcial_CDE/raw/main/country_isos.xlsx'

datateach=pd.read_excel(linkteach)
datateach
# Out:
#                  Country                            Officialstatename  \
# 0            AFGHANISTAN          The Islamic Republic of Afghanistan
# 1                ALBANIA                      The Republic of Albania
# 2                ALGERIA  The People's Democratic Republic of Algeria
# 3                 ANGOLA                       The Republic of Angola
# 4    ANTIGUA AND BARBUDA                          Antigua and Barbuda
# ..                   ...                                          ...
# 166           UZBEKISTAN                   The Republic of Uzbekistan
# 167             VIET NAM           The Socialist Republic of Viet Nam
# 168                YEMEN                        The Republic of Yemen
# 169               ZAMBIA                       The Republic of Zambia
# 170             ZIMBABWE                     The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3
# 0             .af   AF  AFG
# 1             .al   AL  ALB
# 2             .dz   DZ  DZA
# 3             .ao   AO  AGO
# 4             .ag   AG  ATG
# ..            ...  ...  ...
# 166           .uz   UZ  UZB
# 167           .vn   VN  VNM
# 168           .ye   YE  YEM
# 169           .zm   ZM  ZMB
# 170           .zw   ZW  ZWE
#
# [171 rows x 5 columns]

# %%
# Voy a capitalizar los nombres de Country xq los datos del profesor están en mayúsculas
merge2['Country']=merge2['Country'].str.upper()
merge2
# Out:
#                      Country     CO2_en_2019 Renewable Energy score  \
# 0                      CHINA  10,773,248,000              74.113095
# 1              UNITED STATES   5,144,361,000              84.615079
# 2                      INDIA   2,314,738,000              66.711397
# 3                      JAPAN   1,103,234,000              77.894841
# 4                    GERMANY     726,881,000               90.46627
# ..                       ...             ...                    ...
# 87                    RWANDA       1,189,000              58.991964
# 88              SIERRA LEONE         899,000               7.539643
# 89                   ERITREA         798,000                 9.0525
# 90                   BURUNDI         715,000              53.568532
# 91  CENTRAL AFRICAN REPUBLIC         285,000              36.879881
#
#    Energy_Efficiency_score Mineral Fuels
# 0                68.462978    4089959923
# 1                 88.12037    2091889109
# 2                60.267857     881874005
# 3                67.583841       2285200
# 4                77.091049     133090212
# ..                     ...           ...
# 87               21.455026             0
# 88               18.270503             0
# 89               21.180556             0
# 90               12.436618             0
# 91                10.99537             0
#
# [92 rows x 5 columns]

# %%
# merge2.Country
#Onlydata_merge=set(data_merge.Country)-set(merge2.Country)
datateach.Country
# Out:
# 0              AFGHANISTAN
# 1                  ALBANIA
# 2                  ALGERIA
# 3                   ANGOLA
# 4      ANTIGUA AND BARBUDA
#               ...
# 166             UZBEKISTAN
# 167               VIET NAM
# 168                  YEMEN
# 169                 ZAMBIA
# 170               ZIMBABWE
# Name: Country, Length: 171, dtype: object

# %%
merge2.Country
# Out:
# 0                        CHINA
# 1                UNITED STATES
# 2                        INDIA
# 3                        JAPAN
# 4                      GERMANY
#                 ...
# 87                      RWANDA
# 88                SIERRA LEONE
# 89                     ERITREA
# 90                     BURUNDI
# 91    CENTRAL AFRICAN REPUBLIC
# Name: Country, Length: 92, dtype: object

# %%
# 1
onlyD=set(merge2.Country)-set(datateach.Country)
onlyD
# Out:
# {'BOLIVIA',
#  'CENTRAL AFRICAN REPUBLIC',
#  'DOMINICAN REPUBLIC',
#  'ERITREA',
#  'NETHERLANDS',
#  'NIGER',
#  'PHILIPPINES',
#  'SOUTH AFRICA',
#  'SUDAN',
#  'TANZANIA',
#  'UNITED ARAB EMIRATES',
#  'UNITED KINGDOM',
#  'UNITED STATES',
#  'VIETNAM'}

# %%
onlyD2=set(datateach.Country)-set(merge2.Country)
onlyD2
# Out:
# {'ALBANIA',
#  'ANTIGUA AND BARBUDA',
#  'AZERBAIJAN',
#  'BAHAMAS (THE)',
#  'BARBADOS',
#  'BELIZE',
#  'BHUTAN',
#  'BOLIVIA (PLURINATIONAL STATE OF)',
#  'BOSNIA AND HERZEGOVINA',
#  'BOTSWANA',
#  'BRUNEI DARUSSALAM',
#  'BULGARIA',
#  'CABO VERDE',
#  'CENTRAL AFRICAN REPUBLIC (THE)',
#  'COMOROS (THE)',
#  'CONGO (THE DEMOCRATIC REPUBLIC OF THE)',
#  'CONGO (THE)',
#  'COSTA RICA',
#  'CROATIA',
#  'CUBA',
#  'CYPRUS',
#  'CZECHIA',
#  "C√îTE D'IVOIRE",
#  'DJIBOUTI',
#  'DOMINICAN REPUBLIC (THE)',
#  'EGYPT',
#  'EL SALVADOR',
#  'EQUATORIAL GUINEA',
#  'ESTONIA',
#  'ESWATINI',
#  'FIJI',
#  'GABON',
#  'GAMBIA (THE)',
#  'GEORGIA',
#  'GRENADA',
#  'GUINEA-BISSAU',
#  'GUYANA',
#  'HAITI',
#  'HUNGARY',
#  'ICELAND',
#  'IRAN (ISLAMIC REPUBLIC OF)',
#  'IRAQ',
#  'IRELAND',
#  'JAMAICA',
#  'KOREA (THE REPUBLIC OF)',
#  'KYRGYZSTAN',
#  "LAO PEOPLE'S DEMOCRATIC REPUBLIC (THE)",
#  'LATVIA',
#  'LESOTHO',
#  'LIBYA',
#  'LITHUANIA',
#  'LUXEMBOURG',
#  'MALDIVES',
#  'MALTA',
#  'MAURITIUS',
#  'MICRONESIA (FEDERATED STATES OF)',
#  'MOLDOVA (THE REPUBLIC OF)',
#  'MONTENEGRO',
#  'MYANMAR',
#  'NAMIBIA',
#  'NETHERLANDS (THE)',
#  'NEW ZEALAND',
#  'NIGER (THE)',
#  'NORTH MACEDONIA',
#  'NORWAY',
#  'OMAN',
#  'PANAMA',
#  'PAPUA NEW GUINEA',
#  'PARAGUAY',
#  'PHILIPPINES (THE)',
#  'PORTUGAL',
#  'RUSSIAN FEDERATION (THE)',
#  'SAMOA',
#  'SAO TOME AND PRINCIPE',
#  'SERBIA',
#  'SEYCHELLES',
#  'SINGAPORE',
#  'SLOVAKIA',
#  'SLOVENIA',
#  'SOLOMON ISLANDS',
#  'SUDAN (THE)',
#  'SURINAME',
#  'TANZANIA, THE UNITED REPUBLIC OF',
#  'TIMOR-LESTE',
#  'TRINIDAD AND TOBAGO',
#  'TURKEY',
#  'TURKMENISTAN',
#  'UNITED ARAB EMIRATES (THE)',
#  'UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IRELAND (THE)',
#  'UNITED STATES MINOR OUTLYING ISLANDS (THE)',
#  'URUGUAY',
#  'VIET NAM',
#  'YEMEN'}

# %%
# algunos buenos match
from thefuzz import process as fz
[(f,fz.extractOne(f, onlyD2)) for f in sorted(onlyD)]
# Out:
# [('BOLIVIA', ('BOLIVIA (PLURINATIONAL STATE OF)', 90)),
#  ('CENTRAL AFRICAN REPUBLIC', ('CENTRAL AFRICAN REPUBLIC (THE)', 95)),
#  ('DOMINICAN REPUBLIC', ('DOMINICAN REPUBLIC (THE)', 95)),
#  ('ERITREA', ('SERBIA', 62)),
#  ('NETHERLANDS', ('NETHERLANDS (THE)', 95)),
#  ('NIGER', ('NIGER (THE)', 90)),
#  ('PHILIPPINES', ('PHILIPPINES (THE)', 95)),
#  ('SOUTH AFRICA', ('COSTA RICA', 64)),
#  ('SUDAN', ('SUDAN (THE)', 90)),
#  ('TANZANIA', ('TANZANIA, THE UNITED REPUBLIC OF', 90)),
#  ('UNITED ARAB EMIRATES', ('UNITED ARAB EMIRATES (THE)', 95)),
#  ('UNITED KINGDOM',
#   ('UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IRELAND (THE)', 90)),
#  ('UNITED STATES', ('UNITED STATES MINOR OUTLYING ISLANDS (THE)', 90)),
#  ('VIETNAM', ('VIET NAM', 93))]

# %%
# nuevo diccionario
nuevodicc={f:fz.extractOne(f,onlyD)[0] 
                 for f in sorted(onlyD)
                 if fz.extractOne(f,onlyD)[1]>=90}
nuevodicc
# Out:
# {'BOLIVIA': 'BOLIVIA',
#  'CENTRAL AFRICAN REPUBLIC': 'CENTRAL AFRICAN REPUBLIC',
#  'DOMINICAN REPUBLIC': 'DOMINICAN REPUBLIC',
#  'ERITREA': 'ERITREA',
#  'NETHERLANDS': 'NETHERLANDS',
#  'NIGER': 'NIGER',
#  'PHILIPPINES': 'PHILIPPINES',
#  'SOUTH AFRICA': 'SOUTH AFRICA',
#  'SUDAN': 'SUDAN',
#  'TANZANIA': 'TANZANIA',
#  'UNITED ARAB EMIRATES': 'UNITED ARAB EMIRATES',
#  'UNITED KINGDOM': 'UNITED KINGDOM',
#  'UNITED STATES': 'UNITED STATES',
#  'VIETNAM': 'VIETNAM'}

# %%
merge2.Country.replace(to_replace=nuevodicc,inplace=True)

# %%
merge2
# Out:
#                      Country     CO2_en_2019 Renewable Energy score  \
# 0                      CHINA  10,773,248,000              74.113095
# 1              UNITED STATES   5,144,361,000              84.615079
# 2                      INDIA   2,314,738,000              66.711397
# 3                      JAPAN   1,103,234,000              77.894841
# 4                    GERMANY     726,881,000               90.46627
# ..                       ...             ...                    ...
# 87                    RWANDA       1,189,000              58.991964
# 88              SIERRA LEONE         899,000               7.539643
# 89                   ERITREA         798,000                 9.0525
# 90                   BURUNDI         715,000              53.568532
# 91  CENTRAL AFRICAN REPUBLIC         285,000              36.879881
#
#    Energy_Efficiency_score Mineral Fuels
# 0                68.462978    4089959923
# 1                 88.12037    2091889109
# 2                60.267857     881874005
# 3                67.583841       2285200
# 4                77.091049     133090212
# ..                     ...           ...
# 87               21.455026             0
# 88               18.270503             0
# 89               21.180556             0
# 90               12.436618             0
# 91                10.99537             0
#
# [92 rows x 5 columns]

# %%
onlyD=set(merge2.Country)-set(datateach.Country)
onlyD2=set(datateach.Country)-set(merge2.Country)
from thefuzz import process as fz
[(f,fz.extractOne(f, onlyD2)) for f in sorted(onlyD)]
# Out:
# [('BOLIVIA', ('BOLIVIA (PLURINATIONAL STATE OF)', 90)),
#  ('CENTRAL AFRICAN REPUBLIC', ('CENTRAL AFRICAN REPUBLIC (THE)', 95)),
#  ('DOMINICAN REPUBLIC', ('DOMINICAN REPUBLIC (THE)', 95)),
#  ('ERITREA', ('SERBIA', 62)),
#  ('NETHERLANDS', ('NETHERLANDS (THE)', 95)),
#  ('NIGER', ('NIGER (THE)', 90)),
#  ('PHILIPPINES', ('PHILIPPINES (THE)', 95)),
#  ('SOUTH AFRICA', ('COSTA RICA', 64)),
#  ('SUDAN', ('SUDAN (THE)', 90)),
#  ('TANZANIA', ('TANZANIA, THE UNITED REPUBLIC OF', 90)),
#  ('UNITED ARAB EMIRATES', ('UNITED ARAB EMIRATES (THE)', 95)),
#  ('UNITED KINGDOM',
#   ('UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IRELAND (THE)', 90)),
#  ('UNITED STATES', ('UNITED STATES MINOR OUTLYING ISLANDS (THE)', 90)),
#  ('VIETNAM', ('VIET NAM', 93))]

# %%
nuevodicc2={f:fz.extractOne(f,onlyD)[0] 
                 for f in sorted(onlyD)
                 if fz.extractOne(f,onlyD)[1]>=90}
nuevodicc2
# Out:
# {'BOLIVIA': 'BOLIVIA',
#  'CENTRAL AFRICAN REPUBLIC': 'CENTRAL AFRICAN REPUBLIC',
#  'DOMINICAN REPUBLIC': 'DOMINICAN REPUBLIC',
#  'ERITREA': 'ERITREA',
#  'NETHERLANDS': 'NETHERLANDS',
#  'NIGER': 'NIGER',
#  'PHILIPPINES': 'PHILIPPINES',
#  'SOUTH AFRICA': 'SOUTH AFRICA',
#  'SUDAN': 'SUDAN',
#  'TANZANIA': 'TANZANIA',
#  'UNITED ARAB EMIRATES': 'UNITED ARAB EMIRATES',
#  'UNITED KINGDOM': 'UNITED KINGDOM',
#  'UNITED STATES': 'UNITED STATES',
#  'VIETNAM': 'VIETNAM'}

# %%
merge2.Country.replace(to_replace=nuevodicc2,inplace=True)
merge2
# Out:
#                      Country     CO2_en_2019 Renewable Energy score  \
# 0                      CHINA  10,773,248,000              74.113095
# 1              UNITED STATES   5,144,361,000              84.615079
# 2                      INDIA   2,314,738,000              66.711397
# 3                      JAPAN   1,103,234,000              77.894841
# 4                    GERMANY     726,881,000               90.46627
# ..                       ...             ...                    ...
# 87                    RWANDA       1,189,000              58.991964
# 88              SIERRA LEONE         899,000               7.539643
# 89                   ERITREA         798,000                 9.0525
# 90                   BURUNDI         715,000              53.568532
# 91  CENTRAL AFRICAN REPUBLIC         285,000              36.879881
#
#    Energy_Efficiency_score Mineral Fuels
# 0                68.462978    4089959923
# 1                 88.12037    2091889109
# 2                60.267857     881874005
# 3                67.583841       2285200
# 4                77.091049     133090212
# ..                     ...           ...
# 87               21.455026             0
# 88               18.270503             0
# 89               21.180556             0
# 90               12.436618             0
# 91                10.99537             0
#
# [92 rows x 5 columns]

# %%
# Ahora uniré esta data con la anterior, 
# priorizando las filas de la data del profe

# %%
data_merge=datateach.merge(merge2,how='inner',left_on='Country',right_on='Country')
data_merge
# Out:
#         Country                            Officialstatename InternetccTLD  \
# 0   AFGHANISTAN          The Islamic Republic of Afghanistan           .af
# 1       ALGERIA  The People's Democratic Republic of Algeria           .dz
# 2        ANGOLA                       The Republic of Angola           .ao
# 3     ARGENTINA                       The Argentine Republic           .ar
# 4       ARMENIA                      The Republic of Armenia           .am
# ..          ...                                          ...           ...
# 73       UGANDA                       The Republic of Uganda           .ug
# 74      UKRAINE                                      Ukraine           .ua
# 75   UZBEKISTAN                   The Republic of Uzbekistan           .uz
# 76       ZAMBIA                       The Republic of Zambia           .zm
# 77     ZIMBABWE                     The Republic of Zimbabwe           .zw
#
#    iso2 iso3  CO2_en_2019 Renewable Energy score Energy_Efficiency_score  \
# 0    AF  AFG    7,893,000              26.934385               17.898479
# 1    DZ  DZA  151,633,000              51.101032               55.987654
# 2    AO  AGO   19,362,000              17.361071               17.749669
# 3    AR  ARG  193,205,000              52.781026               43.946208
# 4    AM  ARM    6,354,000              63.071833               41.914683
# ..  ...  ...          ...                    ...                     ...
# 73   UG  UGA    5,841,000              53.605742               33.526235
# 74   UA  UKR  185,686,000              63.789405                36.67769
# 75   UZ  UZB  102,965,000              30.059405               50.945216
# 76   ZM  ZMB    6,798,000              46.655607               20.631614
# 77   ZW  ZWE    7,902,000              18.008677               14.313272
#
#    Mineral Fuels
# 0         463200
# 1      142229600
# 2       58979490
# 3       58342500
# 4              0
# ..           ...
# 73             0
# 74      47648536
# 75      50183451
# 76        663345
# 77       3246000
#
# [78 rows x 9 columns]

# %%
data_merge.Country
# Out:
# 0     AFGHANISTAN
# 1         ALGERIA
# 2          ANGOLA
# 3       ARGENTINA
# 4         ARMENIA
#          ...
# 73         UGANDA
# 74        UKRAINE
# 75     UZBEKISTAN
# 76         ZAMBIA
# 77       ZIMBABWE
# Name: Country, Length: 78, dtype: object

# %%
merge2.Country
# Out:
# 0                        CHINA
# 1                UNITED STATES
# 2                        INDIA
# 3                        JAPAN
# 4                      GERMANY
#                 ...
# 87                      RWANDA
# 88                SIERRA LEONE
# 89                     ERITREA
# 90                     BURUNDI
# 91    CENTRAL AFRICAN REPUBLIC
# Name: Country, Length: 92, dtype: object

# %%
# Modificaré el nombre de las columnas
# Official_State_Name, Internet_cc_TLD, iso_2,iso_3, Renewable_Energy_score,Mineral_Fuels
data_merge.rename(columns={'Officialstatename':'Official_State_Name','InternetccTLD':'Internet_CC_TLD','iso2':'ISO_2','iso3':'ISO_3','Renewable Energy score':'Renewable_Energy_score','Mineral Fuels':'Mineral_Fuels'},inplace=True)
data_merge
# Out:
#         Country                          Official_State_Name Internet_CC_TLD  \
# 0   AFGHANISTAN          The Islamic Republic of Afghanistan             .af
# 1       ALGERIA  The People's Democratic Republic of Algeria             .dz
# 2        ANGOLA                       The Republic of Angola             .ao
# 3     ARGENTINA                       The Argentine Republic             .ar
# 4       ARMENIA                      The Republic of Armenia             .am
# ..          ...                                          ...             ...
# 73       UGANDA                       The Republic of Uganda             .ug
# 74      UKRAINE                                      Ukraine             .ua
# 75   UZBEKISTAN                   The Republic of Uzbekistan             .uz
# 76       ZAMBIA                       The Republic of Zambia             .zm
# 77     ZIMBABWE                     The Republic of Zimbabwe             .zw
#
#    ISO_2 ISO_3  CO2_en_2019 Renewable_Energy_score Energy_Efficiency_score  \
# 0     AF   AFG    7,893,000              26.934385               17.898479
# 1     DZ   DZA  151,633,000              51.101032               55.987654
# 2     AO   AGO   19,362,000              17.361071               17.749669
# 3     AR   ARG  193,205,000              52.781026               43.946208
# 4     AM   ARM    6,354,000              63.071833               41.914683
# ..   ...   ...          ...                    ...                     ...
# 73    UG   UGA    5,841,000              53.605742               33.526235
# 74    UA   UKR  185,686,000              63.789405                36.67769
# 75    UZ   UZB  102,965,000              30.059405               50.945216
# 76    ZM   ZMB    6,798,000              46.655607               20.631614
# 77    ZW   ZWE    7,902,000              18.008677               14.313272
#
#    Mineral_Fuels
# 0         463200
# 1      142229600
# 2       58979490
# 3       58342500
# 4              0
# ..           ...
# 73             0
# 74      47648536
# 75      50183451
# 76        663345
# 77       3246000
#
# [78 rows x 9 columns]

# %%
# voy a eliminar espacios de las columnas
data_merge=data_merge.rename(columns=lambda x:x.strip())

# %%
# voy a eliminar espacios antes y después del texto contenido en la columna 'Official_State_Name' y 'Country'
data_merge['Official_State_Name']=data_merge['Official_State_Name'].str.strip()
data_merge['Country']=data_merge['Country'].str.strip()

# %%
# reemplazaré espacios de la columna "Official_State_Name"
data_merge['Official_State_Name']=data_merge['Official_State_Name'].str.replace(' ','_',regex=True)
data_merge
# Out:
#         Country                          Official_State_Name Internet_CC_TLD  \
# 0   AFGHANISTAN          The_Islamic_Republic_of_Afghanistan             .af
# 1       ALGERIA  The_People's_Democratic_Republic_of_Algeria             .dz
# 2        ANGOLA                       The_Republic_of_Angola             .ao
# 3     ARGENTINA                       The_Argentine_Republic             .ar
# 4       ARMENIA                      The_Republic_of_Armenia             .am
# ..          ...                                          ...             ...
# 73       UGANDA                       The_Republic_of_Uganda             .ug
# 74      UKRAINE                                      Ukraine             .ua
# 75   UZBEKISTAN                   The_Republic_of_Uzbekistan             .uz
# 76       ZAMBIA                       The_Republic_of_Zambia             .zm
# 77     ZIMBABWE                     The_Republic_of_Zimbabwe             .zw
#
#    ISO_2 ISO_3  CO2_en_2019 Renewable_Energy_score Energy_Efficiency_score  \
# 0     AF   AFG    7,893,000              26.934385               17.898479
# 1     DZ   DZA  151,633,000              51.101032               55.987654
# 2     AO   AGO   19,362,000              17.361071               17.749669
# 3     AR   ARG  193,205,000              52.781026               43.946208
# 4     AM   ARM    6,354,000              63.071833               41.914683
# ..   ...   ...          ...                    ...                     ...
# 73    UG   UGA    5,841,000              53.605742               33.526235
# 74    UA   UKR  185,686,000              63.789405                36.67769
# 75    UZ   UZB  102,965,000              30.059405               50.945216
# 76    ZM   ZMB    6,798,000              46.655607               20.631614
# 77    ZW   ZWE    7,902,000              18.008677               14.313272
#
#    Mineral_Fuels
# 0         463200
# 1      142229600
# 2       58979490
# 3       58342500
# 4              0
# ..           ...
# 73             0
# 74      47648536
# 75      50183451
# 76        663345
# 77       3246000
#
# [78 rows x 9 columns]

# %%
# Pregunto si todos son dígitos 
data_merge.CO2_en_2019.str.contains(pat=r'\d',regex=True)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#       ...
# 73    True
# 74    True
# 75    True
# 76    True
# 77    True
# Name: CO2_en_2019, Length: 78, dtype: bool

# %%
# elimino las , de 'CO2'
data_merge['CO2_en_2019']=data_merge['CO2_en_2019'].str.replace(',','')

# %%
# quiero convertir mis valores "numéricos" en eso, números
# antes corrijo los NaN en 0 para que lo reconozca
data_merge.replace(np.nan,0,inplace=True)
data_merge
# Out:
#         Country                          Official_State_Name Internet_CC_TLD  \
# 0   AFGHANISTAN          The_Islamic_Republic_of_Afghanistan             .af
# 1       ALGERIA  The_People's_Democratic_Republic_of_Algeria             .dz
# 2        ANGOLA                       The_Republic_of_Angola             .ao
# 3     ARGENTINA                       The_Argentine_Republic             .ar
# 4       ARMENIA                      The_Republic_of_Armenia             .am
# ..          ...                                          ...             ...
# 73       UGANDA                       The_Republic_of_Uganda             .ug
# 74      UKRAINE                                      Ukraine             .ua
# 75   UZBEKISTAN                   The_Republic_of_Uzbekistan             .uz
# 76       ZAMBIA                       The_Republic_of_Zambia             .zm
# 77     ZIMBABWE                     The_Republic_of_Zimbabwe             .zw
#
#    ISO_2 ISO_3 CO2_en_2019 Renewable_Energy_score Energy_Efficiency_score  \
# 0     AF   AFG     7893000              26.934385               17.898479
# 1     DZ   DZA   151633000              51.101032               55.987654
# 2     AO   AGO    19362000              17.361071               17.749669
# 3     AR   ARG   193205000              52.781026               43.946208
# 4     AM   ARM     6354000              63.071833               41.914683
# ..   ...   ...         ...                    ...                     ...
# 73    UG   UGA     5841000              53.605742               33.526235
# 74    UA   UKR   185686000              63.789405                36.67769
# 75    UZ   UZB   102965000              30.059405               50.945216
# 76    ZM   ZMB     6798000              46.655607               20.631614
# 77    ZW   ZWE     7902000              18.008677               14.313272
#
#    Mineral_Fuels
# 0         463200
# 1      142229600
# 2       58979490
# 3       58342500
# 4              0
# ..           ...
# 73             0
# 74      47648536
# 75      50183451
# 76        663345
# 77       3246000
#
# [78 rows x 9 columns]

# %%
data_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  78 non-null     object
#  1   Official_State_Name      78 non-null     object
#  2   Internet_CC_TLD          78 non-null     object
#  3   ISO_2                    78 non-null     object
#  4   ISO_3                    78 non-null     object
#  5   CO2_en_2019              78 non-null     object
#  6   Renewable_Energy_score   78 non-null     object
#  7   Energy_Efficiency_score  78 non-null     object
#  8   Mineral_Fuels            78 non-null     object
# dtypes: object(9)
# memory usage: 5.6+ KB

# %%
data_merge
# Out:
#         Country                          Official_State_Name Internet_CC_TLD  \
# 0   AFGHANISTAN          The_Islamic_Republic_of_Afghanistan             .af
# 1       ALGERIA  The_People's_Democratic_Republic_of_Algeria             .dz
# 2        ANGOLA                       The_Republic_of_Angola             .ao
# 3     ARGENTINA                       The_Argentine_Republic             .ar
# 4       ARMENIA                      The_Republic_of_Armenia             .am
# ..          ...                                          ...             ...
# 73       UGANDA                       The_Republic_of_Uganda             .ug
# 74      UKRAINE                                      Ukraine             .ua
# 75   UZBEKISTAN                   The_Republic_of_Uzbekistan             .uz
# 76       ZAMBIA                       The_Republic_of_Zambia             .zm
# 77     ZIMBABWE                     The_Republic_of_Zimbabwe             .zw
#
#    ISO_2 ISO_3 CO2_en_2019 Renewable_Energy_score Energy_Efficiency_score  \
# 0     AF   AFG     7893000              26.934385               17.898479
# 1     DZ   DZA   151633000              51.101032               55.987654
# 2     AO   AGO    19362000              17.361071               17.749669
# 3     AR   ARG   193205000              52.781026               43.946208
# 4     AM   ARM     6354000              63.071833               41.914683
# ..   ...   ...         ...                    ...                     ...
# 73    UG   UGA     5841000              53.605742               33.526235
# 74    UA   UKR   185686000              63.789405                36.67769
# 75    UZ   UZB   102965000              30.059405               50.945216
# 76    ZM   ZMB     6798000              46.655607               20.631614
# 77    ZW   ZWE     7902000              18.008677               14.313272
#
#    Mineral_Fuels
# 0         463200
# 1      142229600
# 2       58979490
# 3       58342500
# 4              0
# ..           ...
# 73             0
# 74      47648536
# 75      50183451
# 76        663345
# 77       3246000
#
# [78 rows x 9 columns]

# %%
data_merge['Country']=data_merge['Country'].str.replace(' ','_')
data_merge
# Out:
#         Country                          Official_State_Name Internet_CC_TLD  \
# 0   AFGHANISTAN          The_Islamic_Republic_of_Afghanistan             .af
# 1       ALGERIA  The_People's_Democratic_Republic_of_Algeria             .dz
# 2        ANGOLA                       The_Republic_of_Angola             .ao
# 3     ARGENTINA                       The_Argentine_Republic             .ar
# 4       ARMENIA                      The_Republic_of_Armenia             .am
# ..          ...                                          ...             ...
# 73       UGANDA                       The_Republic_of_Uganda             .ug
# 74      UKRAINE                                      Ukraine             .ua
# 75   UZBEKISTAN                   The_Republic_of_Uzbekistan             .uz
# 76       ZAMBIA                       The_Republic_of_Zambia             .zm
# 77     ZIMBABWE                     The_Republic_of_Zimbabwe             .zw
#
#    ISO_2 ISO_3  CO2_en_2019  Renewable_Energy_score  Energy_Efficiency_score  \
# 0     AF   AFG      7893000               26.934385                17.898479
# 1     DZ   DZA    151633000               51.101032                55.987654
# 2     AO   AGO     19362000               17.361071                17.749669
# 3     AR   ARG    193205000               52.781026                43.946208
# 4     AM   ARM      6354000               63.071833                41.914683
# ..   ...   ...          ...                     ...                      ...
# 73    UG   UGA      5841000               53.605742                33.526235
# 74    UA   UKR    185686000               63.789405                36.677690
# 75    UZ   UZB    102965000               30.059405                50.945216
# 76    ZM   ZMB      6798000               46.655607                20.631614
# 77    ZW   ZWE      7902000               18.008677                14.313272
#
#     Mineral_Fuels
# 0          463200
# 1       142229600
# 2        58979490
# 3        58342500
# 4               0
# ..            ...
# 73              0
# 74       47648536
# 75       50183451
# 76         663345
# 77        3246000
#
# [78 rows x 9 columns]

# %%
data_merge['CO2_en_2019']=pd.to_numeric(data_merge['CO2_en_2019'])
data_merge['Renewable_Energy_score']=pd.to_numeric(data_merge['Renewable_Energy_score'])
data_merge['Energy_Efficiency_score']=pd.to_numeric(data_merge['Energy_Efficiency_score'])
data_merge['Mineral_Fuels']=pd.to_numeric(data_merge['Mineral_Fuels'])
data_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  78 non-null     object
#  1   Official_State_Name      78 non-null     object
#  2   Internet_CC_TLD          78 non-null     object
#  3   ISO_2                    78 non-null     object
#  4   ISO_3                    78 non-null     object
#  5   CO2_en_2019              78 non-null     int64
#  6   Renewable_Energy_score   78 non-null     float64
#  7   Energy_Efficiency_score  78 non-null     float64
#  8   Mineral_Fuels            78 non-null     int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 5.6+ KB
